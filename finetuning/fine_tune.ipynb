# %%
import openai

openai.api_key = "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"

# %%
# !openai api fine_tunes.create -t file_prepared.jsonl -m davinci --suffix "ALPHA_JARVIS"
# Out:
# Uploaded file from file_prepared.jsonl: file-PMDQyHWlPP7SungtwC1dnWJ6
# Upload progress:   0%|          | 0.00/23.5k [00:00<?, ?it/s]
# Upload progress: 100%|██████████| 23.5k/23.5k [00:00<00:00, 23.6Mit/s]
# Created fine-tune: ft-pqQXe31FhRl6W9g3ARNMOv5i
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-08-23 00:12:37] Created fine-tune: ft-pqQXe31FhRl6W9g3ARNMOv5i
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-pqQXe31FhRl6W9g3ARNMOv5i

# %%
# !openai api fine_tunes.follow -i ft-pqQXe31FhRl6W9g3ARNMOv5i
# Out:
# [2023-08-23 00:12:37] Created fine-tune: ft-pqQXe31FhRl6W9g3ARNMOv5i
# [2023-08-23 00:22:11] Fine-tune costs $0.87
# [2023-08-23 00:22:12] Fine-tune enqueued. Queue number: 0
# [2023-08-23 00:22:13] Fine-tune started
# [2023-08-23 00:24:46] Completed epoch 1/4
# [2023-08-23 00:25:03] Completed epoch 2/4
# [2023-08-23 00:25:21] Completed epoch 3/4
# [2023-08-23 00:25:38] Completed epoch 4/4
# [2023-08-23 00:26:10] Uploaded model: davinci:ft-personal:alpha-jarvis-2023-08-22-19-26-10
# [2023-08-23 00:26:11] Uploaded result file: file-6eWyGAyMS1T7RddLDfgSnNnU
# [2023-08-23 00:26:12] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-personal:alpha-jarvis-2023-08-22-19-26-10 -p <YOUR_PROMPT>

# %%
# !openai api models.delete -i ft-bwrf2r4BnYXeuroRabACXsW3

# %%
import openai
openai.Model.delete("ft-bwrf2r4BnYXeuroRabACXsW3")

# %%
# !openai api models.delete -i ft-bwrf2r4BnYXeuroRabACXsW3

# %%
openai.FineTune.list()

# %%
# !openai api fine_tunes.follow -i ft-B1a9UopkQUyFsxSADwtR7wkz

# %%
# !openai api fine_tunes.results -i ft-DexNbygrzosLXGG1elevpKFV

# %%
# !openai api fine_tunes.follow -i ft-DexNbygrzosLXGG1elevpKFV
